# %% [markdown]
# ## Find_the_Point

# %%
from IPython.display import Image
Image("Find_the_Point/1.png")

# %%
Image("Find_the_Point/2.png")

# %%
# Code

# %%
a=input("entere").split(' ')
# Out:
# entere1 1

# %%
b=input("entere").split(' ')
# Out:
# entere2 2

# %%
a
# Out:
# ['1', '1']

# %%
b
# Out:
# ['2', '2']
